# %% [markdown]
# ## Part-1 Connect with GoogleDrive

# %%
from google.colab import drive
drive.mount("drive")
# Out:
# Mounted at drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## Make Directort

# %%
import os
if not os.path.isdir("Yolov5Numberplate"):
  os.makedirs("Yolov5Numberplate")

# %%
# %cd Yolov5Numberplate/
# Out:
# /content/drive/MyDrive/Yolov5Numberplate

# %% [markdown]
# ## Clone trained Model Yolov5

# %%
# !git  clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5/
# Out:
# /content/drive/MyDrive/Yolov5Numberplate/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 63.4.3
#     Uninstalling setuptools-63.4.3:
#       Successfully uninstalled setuptools-63.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.3.0 requires setuptools<=64.0.2, but you have setuptools 67.6.0 which is incompatible.
# ...

# %% [markdown]
# ## Uplod the CustomData set

# %%
# !unzip /content/drive/MyDrive/Yolov5Numberplate/dataset.zip -d /content/drive/MyDrive/Yolov5Numberplate/dataset
# Out:
# Archive:  /content/drive/MyDrive/Yolov5Numberplate/dataset.zip
#    creating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/
#    creating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/
#    creating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e1.jpeg
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e10.jpeg
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e11.jpeg
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e12.jpeg
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e13.jpeg
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e14.jpeg
#   inflating: /content/drive/MyDrive/Yolov5Numberplate/dataset/dataset/train/images/e15.jpeg
# ...

# %% [markdown]
# ## Train The Model

# %%
# Train YOLOv5s on COCO128 for 60 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data customdata.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=customdata.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CPU
#
# ...

# %%
# Detect the Photo
# !python detect.py --weights  runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Yolov5Numberplate/yellow.jpeg
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/Yolov5Numberplate/yellow.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/Yolov5Numberplate/yellow.jpeg: 192x640 1 Taxi, 17.8ms
# Speed: 0.6ms pre-process, 17.8ms inference, 18.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# detect the video
# !python detect.py --weights  runs/train/exp2/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Yolov5Numberplate/road.mp4
# Out:
# detect: weights=['runs/train/exp2/weights/last.pt'], source=/content/drive/MyDrive/Yolov5Numberplate/road.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/4330) /content/drive/MyDrive/Yolov5Numberplate/road.mp4: 384x640 (no detections), 15.1ms
# video 1/1 (2/4330) /content/drive/MyDrive/Yolov5Numberplate/road.mp4: 384x640 (no detections), 8.5ms
# ...
